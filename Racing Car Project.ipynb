# %% [markdown]
# # Racing Car Project

# %% [markdown]
# In this project we'll be seeing how to train a neural network with reinforcement learning in order to successfully drive a car in a virtual game environment

# %%
# !pip install torch==1.10.0+cu113 torchvision==0.11.1+cu113 torchaudio===0.10.0+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# Requirement already satisfied: torch==1.10.0+cu113 in c:\users\giuse\appdata\local\programs\python\python39\lib\site-packages (1.10.0+cu113)
# Requirement already satisfied: torchvision==0.11.1+cu113 in c:\users\giuse\appdata\local\programs\python\python39\lib\site-packages (0.11.1+cu113)
# Requirement already satisfied: torchaudio===0.10.0+cu113 in c:\users\giuse\appdata\local\programs\python\python39\lib\site-packages (0.10.0+cu113)
# Requirement already satisfied: typing-extensions in c:\users\giuse\appdata\local\programs\python\python39\lib\site-packages (from torch==1.10.0+cu113) (4.0.1)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in c:\users\giuse\appdata\local\programs\python\python39\lib\site-packages (from torchvision==0.11.1+cu113) (8.3.1)
# Requirement already satisfied: numpy in c:\users\giuse\appdata\local\programs\python\python39\lib\site-packages (from torchvision==0.11.1+cu113) (1.21.4)
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\giuse\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import  DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os
import torch

# %% [markdown]
# ## Test environment

# %% [markdown]
# First of all we create the test environment and render it, after that we start the game without first training the model. Here we expect to have a low score

# %%
env = gym.make("CarRacing-v0")

# %%
env.render()
# Out:
# c:\users\giuse\appdata\local\programs\python\python39\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))

# %%
episodes = 1
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        obs, reward, done, info = env.step(action)
        score+=reward
    print("Episode:{} Score:{}".format(episode, score))
# Out:
# Track generation: 1140..1429 -> 289-tiles track
# Episode:1 Score:-34.02777777777822

# %%
env.close()

# %% [markdown]
# ## Training

# %% [markdown]
# Here we start training the model using Torch. (Disclaimer, running the following lines of code on your computer might not work if you don't have the right graphic card)

# %%
use_cuda = torch.cuda.is_available()
if use_cuda:
    print('__CUDNN VERSION:', torch.backends.cudnn.version())
    print('__Number CUDA Devices:', torch.cuda.device_count())
    print('__CUDA Device Name:',torch.cuda.get_device_name(0))
    print('__CUDA Device Total Memory [GB]:',torch.cuda.get_device_properties(0).total_memory/1e9)
# Out:
# __CUDNN VERSION: 8200
# __Number CUDA Devices: 1
# __CUDA Device Name: NVIDIA GeForce RTX 2060
# __CUDA Device Total Memory [GB]: 6.442123264

# %%
env = DummyVecEnv([lambda: env])

# %%
model = PPO("CnnPolicy", env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# The cell below is where we train our model, the training is gonna take some a few minutes (depending on your pc specs).
# The longer we train our model, the higher the score will be

# %%
model.learn(total_timesteps=10000)
# Out:
# Track generation: 1075..1348 -> 273-tiles track
# Track generation: 1145..1443 -> 298-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 113  |
# |    iterations      | 1    |
# |    time_elapsed    | 17   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1078..1358 -> 280-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 2           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009157797 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.172       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00964    |
# |    std                  | 0.993       |
# |    value_loss           | 0.596       |
# -----------------------------------------
# Track generation: 1088..1371 -> 283-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 3           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011040331 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.0897      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.983       |
# |    value_loss           | 0.474       |
# -----------------------------------------
# Track generation: 1225..1535 -> 310-tiles track
# Track generation: 1035..1304 -> 269-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 4           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010180868 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 0.972       |
# |    value_loss           | 0.604       |
# -----------------------------------------
# Track generation: 1105..1386 -> 281-tiles track
# Track generation: 995..1248 -> 253-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 99        |
# |    iterations           | 5         |
# |    time_elapsed         | 102       |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0150411 |
# |    clip_fraction        | 0.15      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.16     |
# |    explained_variance   | 0.219     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.103     |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -0.0213   |
# |    std                  | 0.966     |
# |    value_loss           | 0.463     |
# ---------------------------------------
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1019..1283 -> 264-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 6           |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012085228 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.0797      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0914      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.965       |
# |    value_loss           | 0.449       |
# -----------------------------------------
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1175..1473 -> 298-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 7           |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.020013088 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0105      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0321     |
# |    std                  | 0.95        |
# |    value_loss           | 0.35        |
# -----------------------------------------
# Track generation: 990..1247 -> 257-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 8           |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018477932 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | -0.00574    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0365      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.025      |
# |    std                  | 0.94        |
# |    value_loss           | 0.292       |
# -----------------------------------------
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1034..1303 -> 269-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 9           |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023108505 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0373      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0263     |
# |    std                  | 0.934       |
# |    value_loss           | 0.392       |
# -----------------------------------------
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1105..1390 -> 285-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 10          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.026610361 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00565    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.04       |
# |    std                  | 0.925       |
# |    value_loss           | 0.318       |
# -----------------------------------------
# Track generation: 1047..1323 -> 276-tiles track
# Track generation: 1094..1372 -> 278-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 11         |
# |    time_elapsed         | 229        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02131917 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4         |
# |    explained_variance   | 0.348      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0165     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0324    |
# |    std                  | 0.915      |
# |    value_loss           | 0.305      |
# ----------------------------------------
# Track generation: 1192..1494 -> 302-tiles track
# Track generation: 1133..1427 -> 294-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 12          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.028928243 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0383      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0336     |
# |    std                  | 0.902       |
# |    value_loss           | 0.471       |
# -----------------------------------------
# Track generation: 1185..1485 -> 300-tiles track
# Track generation: 1295..1623 -> 328-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 13          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.032231405 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0934      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0322     |
# |    std                  | 0.885       |
# |    value_loss           | 0.476       |
# -----------------------------------------
# Track generation: 1069..1346 -> 277-tiles track
# Track generation: 1244..1559 -> 315-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 14          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.059215635 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0523     |
# |    std                  | 0.87        |
# |    value_loss           | 0.282       |
# -----------------------------------------
# Track generation: 1324..1659 -> 335-tiles track
# Track generation: 1420..1779 -> 359-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1230..1542 -> 312-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 15         |
# |    time_elapsed         | 316        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03833337 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.82      |
# |    explained_variance   | 0.773      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00679    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0403    |
# |    std                  | 0.862      |
# |    value_loss           | 0.356      |
# ----------------------------------------
# Track generation: 1220..1529 -> 309-tiles track
# Track generation: 1247..1563 -> 316-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 16          |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.059249412 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0374     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0437     |
# |    std                  | 0.849       |
# |    value_loss           | 0.142       |
# -----------------------------------------
# Track generation: 1081..1355 -> 274-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 17          |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.040025014 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0432     |
# |    std                  | 0.839       |
# |    value_loss           | 0.347       |
# -----------------------------------------
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1162..1457 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 18         |
# |    time_elapsed         | 381        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.04504414 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.71      |
# |    explained_variance   | 0.843      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0105    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0366    |
# |    std                  | 0.833      |
# |    value_loss           | 0.503      |
# ----------------------------------------
# Track generation: 1072..1349 -> 277-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 19          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.049691074 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0359     |
# |    std                  | 0.822       |
# |    value_loss           | 0.309       |
# -----------------------------------------
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 20         |
# |    time_elapsed         | 426        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.06382162 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.64      |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0571     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0367    |
# |    std                  | 0.813      |
# |    value_loss           | 0.471      |
# ----------------------------------------
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1395..1751 -> 356-tiles track
# Track generation: 1023..1287 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1215..1523 -> 308-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 21          |
# |    time_elapsed         | 449         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.046703286 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0337      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0397     |
# |    std                  | 0.801       |
# |    value_loss           | 0.634       |
# -----------------------------------------
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1116..1399 -> 283-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 22         |
# |    time_elapsed         | 471        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.06110602 |
# |    clip_fraction        | 0.389      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0685    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0352    |
# |    std                  | 0.794      |
# |    value_loss           | 0.279      |
# ----------------------------------------
# Track generation: 1211..1518 -> 307-tiles track
# Track generation: 1306..1637 -> 331-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 23          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.050754976 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00364     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.792       |
# |    value_loss           | 0.417       |
# -----------------------------------------
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1284..1609 -> 325-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 24          |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.040190596 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.351       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0228     |
# |    std                  | 0.788       |
# |    value_loss           | 2.55        |
# -----------------------------------------
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1189..1490 -> 301-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 25         |
# |    time_elapsed         | 538        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.06658345 |
# |    clip_fraction        | 0.394      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.117      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0267    |
# |    std                  | 0.78       |
# |    value_loss           | 1.05       |
# ----------------------------------------
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1197..1501 -> 304-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 26         |
# |    time_elapsed         | 560        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.06613495 |
# |    clip_fraction        | 0.401      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.48      |
# |    explained_variance   | 0.853      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.557      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0216    |
# |    std                  | 0.777      |
# |    value_loss           | 1.43       |
# ----------------------------------------
# Track generation: 1128..1418 -> 290-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 27         |
# |    time_elapsed         | 583        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.05487094 |
# |    clip_fraction        | 0.364      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.46      |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.172      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0241    |
# |    std                  | 0.768      |
# |    value_loss           | 0.809      |
# ----------------------------------------
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1230..1542 -> 312-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 28         |
# |    time_elapsed         | 606        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.04758959 |
# |    clip_fraction        | 0.37       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.43      |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.253      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0292    |
# |    std                  | 0.759      |
# |    value_loss           | 1.68       |
# ----------------------------------------
# Track generation: 1137..1426 -> 289-tiles track
# Track generation: 1207..1513 -> 306-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 29          |
# |    time_elapsed         | 627         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.057155747 |
# |    clip_fraction        | 0.415       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.4        |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0117     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0249     |
# |    std                  | 0.753       |
# |    value_loss           | 0.487       |
# -----------------------------------------
# Track generation: 994..1256 -> 262-tiles track
# Track generation: 1356..1699 -> 343-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 30          |
# |    time_elapsed         | 649         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.040270522 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.096       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0259     |
# |    std                  | 0.751       |
# |    value_loss           | 0.824       |
# -----------------------------------------
# Track generation: 1227..1538 -> 311-tiles track
# Track generation: 1242..1556 -> 314-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 31          |
# |    time_elapsed         | 670         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.030613849 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.133       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0251     |
# |    std                  | 0.741       |
# |    value_loss           | 1.01        |
# -----------------------------------------
# Track generation: 1127..1415 -> 288-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1147..1438 -> 291-tiles track
# Track generation: 1110..1398 -> 288-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 32         |
# |    time_elapsed         | 692        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.05400733 |
# |    clip_fraction        | 0.362      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.31      |
# |    explained_variance   | 0.887      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.169      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0231    |
# |    std                  | 0.732      |
# |    value_loss           | 1.46       |
# ----------------------------------------
# Track generation: 1049..1315 -> 266-tiles track
# Track generation: 1207..1517 -> 310-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 33          |
# |    time_elapsed         | 714         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.052844867 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.236       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0298     |
# |    std                  | 0.72        |
# |    value_loss           | 0.869       |
# -----------------------------------------
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1223..1533 -> 310-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 34         |
# |    time_elapsed         | 735        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.07580136 |
# |    clip_fraction        | 0.399      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0358     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0145    |
# |    std                  | 0.716      |
# |    value_loss           | 0.348      |
# ----------------------------------------
# Track generation: 1255..1573 -> 318-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 35          |
# |    time_elapsed         | 757         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.038369983 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.599       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.713       |
# |    value_loss           | 1.36        |
# -----------------------------------------
# Track generation: 1045..1310 -> 265-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 36         |
# |    time_elapsed         | 778        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.06680203 |
# |    clip_fraction        | 0.39       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.914      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.193      |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0241    |
# |    std                  | 0.709      |
# |    value_loss           | 1.25       |
# ----------------------------------------
# Track generation: 1284..1619 -> 335-tiles track
# Track generation: 1141..1430 -> 289-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 37          |
# |    time_elapsed         | 801         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.057959944 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.706       |
# |    value_loss           | 1.15        |
# -----------------------------------------
# Track generation: 1168..1464 -> 296-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 38         |
# |    time_elapsed         | 824        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.08736109 |
# |    clip_fraction        | 0.383      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0768     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0277    |
# |    std                  | 0.697      |
# |    value_loss           | 0.672      |
# ----------------------------------------
# Track generation: 1090..1367 -> 277-tiles track
# Track generation: 988..1245 -> 257-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 39         |
# |    time_elapsed         | 846        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.07890025 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.304      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0295    |
# |    std                  | 0.692      |
# |    value_loss           | 1.29       |
# ----------------------------------------
# Track generation: 1272..1594 -> 322-tiles track
# Track generation: 868..1095 -> 227-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 40         |
# |    time_elapsed         | 869        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.07894936 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.94       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0713     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0145    |
# |    std                  | 0.691      |
# |    value_loss           | 1.04       |
# ----------------------------------------
# Track generation: 1097..1376 -> 279-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 41         |
# |    time_elapsed         | 891        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.07120307 |
# |    clip_fraction        | 0.438      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.384      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0103    |
# |    std                  | 0.688      |
# |    value_loss           | 2.84       |
# ----------------------------------------
# Track generation: 1074..1351 -> 277-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 42          |
# |    time_elapsed         | 914         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.078685895 |
# |    clip_fraction        | 0.431       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0338      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.686       |
# |    value_loss           | 0.651       |
# -----------------------------------------
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1302..1632 -> 330-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 43         |
# |    time_elapsed         | 936        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.05847176 |
# |    clip_fraction        | 0.379      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.07      |
# |    explained_variance   | 0.87       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.894      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0124    |
# |    std                  | 0.684      |
# |    value_loss           | 6.41       |
# ----------------------------------------
# Track generation: 1363..1708 -> 345-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 44          |
# |    time_elapsed         | 959         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.058711722 |
# |    clip_fraction        | 0.396       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.488       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.682       |
# |    value_loss           | 3.96        |
# -----------------------------------------
# Track generation: 1062..1331 -> 269-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 45          |
# |    time_elapsed         | 982         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.055831883 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.187       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.677       |
# |    value_loss           | 1.7         |
# -----------------------------------------
# Track generation: 1111..1398 -> 287-tiles track
# Track generation: 1151..1442 -> 291-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 46          |
# |    time_elapsed         | 1005        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.045335747 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.52        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00858    |
# |    std                  | 0.675       |
# |    value_loss           | 3.38        |
# -----------------------------------------
# Track generation: 1041..1314 -> 273-tiles track
# Track generation: 1032..1294 -> 262-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 47          |
# |    time_elapsed         | 1028        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.067019194 |
# |    clip_fraction        | 0.418       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.215       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0208     |
# |    std                  | 0.668       |
# |    value_loss           | 1.7         |
# -----------------------------------------
# Track generation: 1033..1296 -> 263-tiles track
# Track generation: 1031..1293 -> 262-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 48         |
# |    time_elapsed         | 1050       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.05955406 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.98      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.264      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0118    |
# |    std                  | 0.666      |
# |    value_loss           | 1.69       |
# ----------------------------------------
# Track generation: 1051..1318 -> 267-tiles track
# Track generation: 1011..1276 -> 265-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 49         |
# |    time_elapsed         | 1072       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.06502902 |
# |    clip_fraction        | 0.371      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.96      |
# |    explained_variance   | 0.911      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.228      |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0225    |
# |    std                  | 0.658      |
# |    value_loss           | 2.26       |
# ----------------------------------------

# %%
 evaluate_policy(model, env, n_eval_episodes=3, render= True)
# Out:
# Track generation: 1267..1588 -> 321-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1145..1435 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# (182.5498843540748, 115.31087818476664)

# %%
env.close()
